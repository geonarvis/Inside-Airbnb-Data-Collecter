# %%
import iacollector

# %%
cities = iacollector.citylist()
# Out:
# City                                     Date
# -------------------------------------------------------
# Albany, New York, United States          2025-06-09
# Amsterdam, North Holland, The Netherlands 2025-06-09
# Antwerp, Flemish Region, Belgium         2025-03-21
# Asheville, North Carolina, United States 2025-06-17
# Athens, Attica, Greece                   2025-06-24
# Austin, Texas, United States             2025-06-13
# Bangkok, Central Thailand, Thailand      2025-03-19
# Barcelona, Catalonia, Spain              2025-06-12
# Barossa Valley, South Australia, Australia 2025-06-25
# Barwon South West, Vic, Victoria, Australia 2025-03-21
# Beijing, Beijing, China                  2024-12-27
# Belize, Belize, Belize                   2025-03-23
# Bergamo, Lombardia, Italy                2025-03-27
# Berlin, Berlin, Germany                  2025-06-20
# Bologna, Emilia-Romagna, Italy           2025-06-19
# Bordeaux, Nouvelle-Aquitaine, France     2025-06-15
# ...

# %%
iacollector.citydownload(["amsterdam","london","paris", "barcelona","new york city","tokyo"], downloadpath="all")

# %%
iacollector.tosql(db_password="7330", selected_detail=True, include_calendar=False)
# Out:
# Step 1: Decompressing .gz files...
#
# Step 2: Loading detail data to ia_detail database (calendar: disabled, columns: selected columns)...
# Created database: ia_detail
# Skipping calendar_detail.csv (calendar disabled)
# Loading barcelona.reviews_2025_03_05
# Loading barcelona.listings_2025_03_05
#     Selected 48 out of 79 columns
# Skipping calendar_detail.csv (calendar disabled)
# Loading paris.reviews_2025_03_03
# Loading paris.listings_2025_03_03
#     Selected 48 out of 79 columns
# Skipping calendar_detail.csv (calendar disabled)
# Loading new_york_city.reviews_2025_05_01
# Loading new_york_city.listings_2025_05_01
#     Selected 48 out of 79 columns
# Skipping calendar_detail.csv (calendar disabled)
# Loading tokyo.reviews_2025_03_23
# Loading tokyo.listings_2025_03_23
#     Selected 48 out of 79 columns
# Skipping calendar_detail.csv (calendar disabled)
# Loading london.reviews_2025_03_04
# Loading london.listings_2025_03_04
#     Selected 48 out of 79 columns
# ...

# %%
iacollector.createhosts(db_password="7330")
# Out:
# Found 6 listings tables
# Processing amsterdam.listings_2025_06_09 -> hosts_2025_06_09
#     Created amsterdam.hosts_2025_06_09 with 8930 hosts
# Processing barcelona.listings_2025_03_05 -> hosts_2025_03_05
#     Created barcelona.hosts_2025_03_05 with 6892 hosts
# Processing london.listings_2025_03_04 -> hosts_2025_03_04
#     Created london.hosts_2025_03_04 with 55395 hosts
# Processing new_york_city.listings_2025_05_01 -> hosts_2025_05_01
#     Created new_york_city.hosts_2025_05_01 with 21989 hosts
# Processing paris.listings_2025_03_03 -> hosts_2025_03_03
#     Created paris.hosts_2025_03_03 with 63103 hosts
# Processing tokyo.listings_2025_03_23 -> hosts_2025_03_23
#     Created tokyo.hosts_2025_03_23 with 4975 hosts
